# %%
import pandas as pd
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, accuracy_score
from sklearn.preprocessing import StandardScaler
from imblearn.over_sampling import SMOTE
from joblib import dump, load
import yfinance as yf
import time
import os

# Step 1: Specify the directory containing your CSV files
directory = r"C:\Users\tanis\Downloads\archive"

# List all files in the directory
file_names = [f for f in os.listdir(directory) if f.endswith('.csv')]

for file_name in file_names:
    print(f"Processing file: {file_name}")
    
    # Step 2: Load data and strip any leading/trailing spaces in column names
    data = pd.read_csv(os.path.join(directory, file_name))
    data.columns = data.columns.str.strip()  # Clean column names

    # Step 3: Basic preprocessing
    data.dropna(inplace=True)  # Handle missing values
    
    # Example feature engineering
    data['price_change'] = data['Close'].pct_change()  # Percentage change in closing price
    data['volume_change'] = data['Volume'].pct_change()  # Percentage change in volume
    data['price_moving_avg'] = data['Close'].rolling(window=5).mean()  # 5-period moving average for price
    data['volume_moving_avg'] = data['Volume'].rolling(window=5).mean()  # 5-period moving average for volume
    
    # Create labels (dummy example, adjust as needed)
    data['label'] = (data['price_change'].abs() > 0.05) & (data['volume_change'].abs() > 0.1)
    
    # Drop columns that are not needed for modeling, ignoring missing columns
    columns_to_drop = ['Date', 'Symbol', 'Series', 'Prev Close', 'Open', 'High', 'Low', 'Last', 'VWAP', 'Turnover', 'Trades', 'Deliverable Volume', '%Deliverable']
    data.drop(columns=columns_to_drop, axis=1, inplace=True, errors='ignore')
    
    # Drop rows with NaN values after feature engineering
    data.dropna(inplace=True)

    # Step 4: Split data into features and labels
    X = data[['price_change', 'volume_change', 'price_moving_avg', 'volume_moving_avg']]
    y = data['label']
    
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)
    
    # Step 5: Apply SMOTE to handle class imbalance
    smote = SMOTE(random_state=42)
    X_resampled, y_resampled = smote.fit_resample(X_train, y_train)
    
    # Step 6: Normalize the data
    scaler = StandardScaler()
    X_resampled_scaled = scaler.fit_transform(X_resampled)
    X_test_scaled = scaler.transform(X_test)
    
    # Step 7: Hyperparameter tuning using GridSearchCV
    param_grid = {
        'n_estimators': [100, 200],
        'max_depth': [10, 20, None],
        'min_samples_split': [2, 5]
    }
    
    grid_search = GridSearchCV(RandomForestClassifier(random_state=42, class_weight='balanced'), param_grid, cv=3)
    grid_search.fit(X_resampled_scaled, y_resampled)
    
    # Best model
    best_model = grid_search.best_estimator_
    
    # Step 8: Evaluate the model
    y_pred = best_model.predict(X_test_scaled)
    print(f"Results for {file_name}:")
    print("Accuracy:", accuracy_score(y_test, y_pred))
    print("Classification Report:\n", classification_report(y_test, y_pred))
    print("\n" + "="*50 + "\n")
    
    # Save the trained model to a file
    model_filename = 'random_forest_model.joblib'
    dump(best_model, model_filename)
    print(f"Model saved to {model_filename}")

# Load the trained model
model = load('random_forest_model.joblib')
print("Model loaded successfully")

# Step 9: Function to fetch real-time data
def fetch_real_time_data(symbol):
    # Fetch historical data
    data = yf.download(symbol, period="1d", interval="1m")
    return data

# Step 10: Preprocess the real-time data
def preprocess_data(data):
    # Feature engineering and preprocessing
    data['price_change'] = data['Close'].pct_change()
    data['volume_change'] = data['Volume'].pct_change()
    data['price_moving_avg'] = data['Close'].rolling(window=5).mean()
    data['volume_moving_avg'] = data['Volume'].rolling(window=5).mean()
    
    # Drop rows with NaN values
    data.dropna(inplace=True)
    
    # Select features
    X = data[['price_change', 'volume_change', 'price_moving_avg', 'volume_moving_avg']]
    return X

# Step 11: Function to track and predict real-time data for symbols
def track_symbols(symbols):
    # Real-time tracking loop
    while True:
        for symbol in symbols:
            print(f"Processing symbol: {symbol}")
            
            # Fetch real-time data
            data = fetch_real_time_data(symbol)
            
            if not data.empty:
                # Preprocess the data
                X = preprocess_data(data)
                X = X.astype('float64')
                
                if not X.empty:
                    # Make prediction
                    prediction = model.predict(X.tail(1))  # Predict based on the latest available data
                    print(f"Real-time prediction for {symbol}: {'Positive' if prediction[0] else 'Negative'}")
            
            print("-" * 50)
        
        # Wait for a while before fetching new data (e.g., 1 hour)
        time.sleep(3600)

# List of symbols to track
symbols = [
    # Stock Exchanges (example tickers, adjust as needed)
    "AAPL",    # Apple
    "GOOGL",   # Alphabet
    "MSFT",    # Microsoft
    
    # Forex Pairs
    "EURUSD=X", # EUR/USD
    "GBPUSD=X", # GBP/USD
    "JPY=X",    # JPY/USD
    
    # Cryptocurrencies
    "BTC-USD",  # Bitcoin
    "ETH-USD",  # Ethereum
]

# Start tracking the symbols
track_symbols(symbols)
# Out:
# Processing file: ADANIPORTS.csv
# Results for ADANIPORTS.csv:
# Accuracy: 0.9293478260869565
# Classification Report:
#                precision    recall  f1-score   support
#
#        False       1.00      0.93      0.96       704
#         True       0.38      1.00      0.55        32
#
#     accuracy                           0.93       736
#    macro avg       0.69      0.96      0.76       736
# weighted avg       0.97      0.93      0.94       736
#
#
# ==================================================
#
# Model saved to random_forest_model.joblib
# Processing file: ASIANPAINT.csv
# Results for ASIANPAINT.csv:
# Accuracy: 0.9619565217391305
# Classification Report:
#                precision    recall  f1-score   support
#
#        False       0.99      0.97      0.98       724
#         True       0.21      0.50      0.30        12
#
#     accuracy                           0.96       736
#    macro avg       0.60      0.73      0.64       736
# weighted avg       0.98      0.96      0.97       736
#
#
# ==================================================
#
# Model saved to random_forest_model.joblib
# Processing file: AXISBANK.csv
# Results for AXISBANK.csv:
# Accuracy: 0.938858695652174
# Classification Report:
#                precision    recall  f1-score   support
#
#        False       1.00      0.94      0.97       708
#         True       0.37      0.89      0.53        28
#
#     accuracy                           0.94       736
#    macro avg       0.68      0.92      0.75       736
# weighted avg       0.97      0.94      0.95       736
#
#
# ==================================================
#
# Model saved to random_forest_model.joblib
# Processing file: BAJAJ-AUTO.csv
# Results for BAJAJ-AUTO.csv:
# Accuracy: 0.9565217391304348
# Classification Report:
#                precision    recall  f1-score   support
#
#        False       1.00      0.96      0.98       730
#         True       0.12      0.67      0.20         6
#
#     accuracy                           0.96       736
#    macro avg       0.56      0.81      0.59       736
# weighted avg       0.99      0.96      0.97       736
#
#
# ==================================================
#
# Model saved to random_forest_model.joblib
# Processing file: BAJAJFINSV.csv
# Results for BAJAJFINSV.csv:
# Accuracy: 0.9646739130434783
# Classification Report:
#                precision    recall  f1-score   support
#
#        False       1.00      0.96      0.98       717
#         True       0.42      1.00      0.59        19
#
#     accuracy                           0.96       736
#    macro avg       0.71      0.98      0.79       736
# weighted avg       0.99      0.96      0.97       736
#
#
# ==================================================
#
# Model saved to random_forest_model.joblib
# Processing file: BAJFINANCE.csv
# Results for BAJFINANCE.csv:
# Accuracy: 0.9497282608695652
# Classification Report:
#                precision    recall  f1-score   support
#
#        False       1.00      0.95      0.97       708
#         True       0.43      0.93      0.58        28
#
#     accuracy                           0.95       736
#    macro avg       0.71      0.94      0.78       736
# weighted avg       0.98      0.95      0.96       736
#
#
# ==================================================
#
# Model saved to random_forest_model.joblib
# Processing file: HEROMOTOCO.csv
# Results for HEROMOTOCO.csv:
# Accuracy: 0.9565217391304348
# Classification Report:
#                precision    recall  f1-score   support
#
#        False       1.00      0.96      0.98       726
#         True       0.23      0.90      0.36        10
#
#     accuracy                           0.96       736
#    macro avg       0.61      0.93      0.67       736
# weighted avg       0.99      0.96      0.97       736
#
#
# ==================================================
#
# Model saved to random_forest_model.joblib
# Processing file: HINDALCO.csv
# Results for HINDALCO.csv:
# Accuracy: 0.9198369565217391
# Classification Report:
#                precision    recall  f1-score   support
#
#        False       1.00      0.92      0.96       712
#         True       0.29      1.00      0.45        24
#
#     accuracy                           0.92       736
#    macro avg       0.64      0.96      0.70       736
# weighted avg       0.98      0.92      0.94       736
#
#
# ==================================================
#
# Model saved to random_forest_model.joblib
# Processing file: HINDUNILVR.csv
# Results for HINDUNILVR.csv:
# Accuracy: 0.9918478260869565
# Classification Report:
#                precision    recall  f1-score   support
#
#        False       1.00      0.99      1.00       729
#         True       0.55      0.86      0.67         7
#
#     accuracy                           0.99       736
#    macro avg       0.77      0.93      0.83       736
# weighted avg       0.99      0.99      0.99       736
#
#
# ==================================================
#
# Model saved to random_forest_model.joblib
# Processing file: ICICIBANK.csv
# Results for ICICIBANK.csv:
# Accuracy: 0.9415760869565217
# Classification Report:
#                precision    recall  f1-score   support
#
#        False       1.00      0.94      0.97       711
#         True       0.35      0.88      0.51        25
#
#     accuracy                           0.94       736
#    macro avg       0.68      0.91      0.74       736
# weighted avg       0.97      0.94      0.95       736
#
#
# ==================================================
#
# Model saved to random_forest_model.joblib
# Processing file: INDUSINDBK.csv
# Results for INDUSINDBK.csv:
# Accuracy: 0.9442934782608695
# Classification Report:
#                precision    recall  f1-score   support
#
#        False       1.00      0.94      0.97       711
#         True       0.38      1.00      0.55        25
#
#     accuracy                           0.94       736
#    macro avg       0.69      0.97      0.76       736
# weighted avg       0.98      0.94      0.96       736
#
#
# ==================================================
#
# Model saved to random_forest_model.joblib
# Processing file: INFY.csv
# Results for INFY.csv:
# Accuracy: 0.9741847826086957
# Classification Report:
#                precision    recall  f1-score   support
#
#        False       1.00      0.97      0.99       719
#         True       0.47      1.00      0.64        17
#
#     accuracy                           0.97       736
#    macro avg       0.74      0.99      0.81       736
# weighted avg       0.99      0.97      0.98       736
#
#
# ==================================================
#
# Model saved to random_forest_model.joblib
# Processing file: IOC.csv
# Results for IOC.csv:
# Accuracy: 0.9456521739130435
# Classification Report:
#                precision    recall  f1-score   support
#
#        False       1.00      0.95      0.97       722
#         True       0.25      0.93      0.39        14
#
#     accuracy                           0.95       736
#    macro avg       0.62      0.94      0.68       736
# weighted avg       0.98      0.95      0.96       736
#
#
# ==================================================
#
# Model saved to random_forest_model.joblib
# Processing file: ITC.csv
# Results for ITC.csv:
# Accuracy: 0.9741847826086957
# Classification Report:
#                precision    recall  f1-score   support
#
#        False       1.00      0.98      0.99       723
#         True       0.38      0.77      0.51        13
#
#     accuracy                           0.97       736
#    macro avg       0.69      0.87      0.75       736
# weighted avg       0.98      0.97      0.98       736
#
#
# ==================================================
#
# Model saved to random_forest_model.joblib
# Processing file: JSWSTEEL.csv
# Results for JSWSTEEL.csv:
# Accuracy: 0.938858695652174
# Classification Report:
#                precision    recall  f1-score   support
#
#        False       1.00      0.94      0.97       721
#         True       0.24      0.93      0.38        15
#
#     accuracy                           0.94       736
#    macro avg       0.62      0.94      0.68       736
# weighted avg       0.98      0.94      0.96       736
#
#
# ==================================================
#
# Model saved to random_forest_model.joblib
# Processing file: KOTAKBANK.csv
# Results for KOTAKBANK.csv:
# Accuracy: 0.9565217391304348
# Classification Report:
#                precision    recall  f1-score   support
#
#        False       1.00      0.96      0.98       726
#         True       0.23      0.90      0.36        10
#
#     accuracy                           0.96       736
#    macro avg       0.61      0.93      0.67       736
# weighted avg       0.99      0.96      0.97       736
#
#
# ==================================================
#
# Model saved to random_forest_model.joblib
# Processing file: LT.csv
# Results for LT.csv:
# Accuracy: 0.9578804347826086
# Classification Report:
#                precision    recall  f1-score   support
#
#        False       1.00      0.96      0.98       718
#         True       0.36      0.94      0.52        18
#
#     accuracy                           0.96       736
#    macro avg       0.68      0.95      0.75       736
# weighted avg       0.98      0.96      0.97       736
#
#
# ==================================================
#
# Model saved to random_forest_model.joblib
# Processing file: MARUTI.csv
# Results for MARUTI.csv:
# Accuracy: 0.9755434782608695
# Classification Report:
#                precision    recall  f1-score   support
#
#        False       0.99      0.98      0.99       719
#         True       0.48      0.76      0.59        17
#
#     accuracy                           0.98       736
#    macro avg       0.74      0.87      0.79       736
# weighted avg       0.98      0.98      0.98       736
#
#
# ==================================================
#
# Model saved to random_forest_model.joblib
# Processing file: MM.csv
# Results for MM.csv:
# Accuracy: 0.9402173913043478
# Classification Report:
#                precision    recall  f1-score   support
#
#        False       0.99      0.95      0.97       720
#         True       0.22      0.69      0.33        16
#
#     accuracy                           0.94       736
#    macro avg       0.61      0.82      0.65       736
# weighted avg       0.98      0.94      0.95       736
#
#
# ==================================================
#
# Model saved to random_forest_model.joblib
# Processing file: NESTLEIND.csv
# Results for NESTLEIND.csv:
# Accuracy: 0.9850543478260869
# Classification Report:
#                precision    recall  f1-score   support
#
#        False       1.00      0.99      0.99       727
#         True       0.44      0.89      0.59         9
#
#     accuracy                           0.99       736
#    macro avg       0.72      0.94      0.79       736
# weighted avg       0.99      0.99      0.99       736
#
#
# ==================================================
#
# Model saved to random_forest_model.joblib
# Processing file: NTPC.csv
# Results for NTPC.csv:
# Accuracy: 0.9619565217391305
# Classification Report:
#                precision    recall  f1-score   support
#
#        False       1.00      0.97      0.98       728
#         True       0.17      0.62      0.26         8
#
#     accuracy                           0.96       736
#    macro avg       0.58      0.80      0.62       736
# weighted avg       0.99      0.96      0.97       736
#
#
# ==================================================
#
# Model saved to random_forest_model.joblib
# Processing file: ONGC.csv
# Results for ONGC.csv:
# Accuracy: 0.936141304347826
# Classification Report:
#                precision    recall  f1-score   support
#
#        False       1.00      0.93      0.97       721
#         True       0.24      1.00      0.39        15
#
#     accuracy                           0.94       736
#    macro avg       0.62      0.97      0.68       736
# weighted avg       0.98      0.94      0.95       736
#
#
# ==================================================
#
# Model saved to random_forest_model.joblib
# Processing file: POWERGRID.csv
# Results for POWERGRID.csv:
# Accuracy: 0.9782608695652174
# Classification Report:
#                precision    recall  f1-score   support
#
#        False       1.00      0.98      0.99       735
#         True       0.00      0.00      0.00         1
#
#     accuracy                           0.98       736
#    macro avg       0.50      0.49      0.49       736
# weighted avg       1.00      0.98      0.99       736
#
#
# ==================================================
#
# Model saved to random_forest_model.joblib
# Processing file: RELIANCE.csv
# Results for RELIANCE.csv:
# Accuracy: 0.96875
# Classification Report:
#                precision    recall  f1-score   support
#
#        False       0.99      0.98      0.98       727
#         True       0.18      0.44      0.26         9
#
#     accuracy                           0.97       736
#    macro avg       0.59      0.71      0.62       736
# weighted avg       0.98      0.97      0.98       736
#
#
# ==================================================
#
# Model saved to random_forest_model.joblib
# Processing file: SBIN.csv
# Results for SBIN.csv:
# Accuracy: 0.9551630434782609
# Classification Report:
#                precision    recall  f1-score   support
#
#        False       1.00      0.96      0.98       709
#         True       0.45      0.93      0.60        27
#
#     accuracy                           0.96       736
#    macro avg       0.72      0.94      0.79       736
# weighted avg       0.98      0.96      0.96       736
#
#
# ==================================================
#
# Model saved to random_forest_model.joblib
# Processing file: SHREECEM.csv
# Results for SHREECEM.csv:
# Accuracy: 0.9741847826086957
# Classification Report:
#                precision    recall  f1-score   support
#
#        False       1.00      0.98      0.99       723
#         True       0.39      0.85      0.54        13
#
#     accuracy                           0.97       736
#    macro avg       0.70      0.91      0.76       736
# weighted avg       0.99      0.97      0.98       736
#
#
# ==================================================
#
# Model saved to random_forest_model.joblib
# Processing file: SUNPHARMA.csv
# Results for SUNPHARMA.csv:
# Accuracy: 0.9497282608695652
# Classification Report:
#                precision    recall  f1-score   support
#
#        False       1.00      0.95      0.97       724
#         True       0.23      0.92      0.37        12
#
#     accuracy                           0.95       736
#    macro avg       0.62      0.93      0.67       736
# weighted avg       0.99      0.95      0.96       736
#
#
# ==================================================
#
# Model saved to random_forest_model.joblib
# Processing file: TATAMOTORS.csv
# Results for TATAMOTORS.csv:
# Accuracy: 0.9402173913043478
# Classification Report:
#                precision    recall  f1-score   support
#
#        False       1.00      0.94      0.97       699
#         True       0.46      0.97      0.62        37
#
#     accuracy                           0.94       736
#    macro avg       0.73      0.96      0.79       736
# weighted avg       0.97      0.94      0.95       736
#
#
# ==================================================
#
# Model saved to random_forest_model.joblib
# Processing file: TATASTEEL.csv
# Results for TATASTEEL.csv:
# Accuracy: 0.9239130434782609
# Classification Report:
#                precision    recall  f1-score   support
#
#        False       1.00      0.92      0.96       711
#         True       0.30      0.96      0.46        25
#
#     accuracy                           0.92       736
#    macro avg       0.65      0.94      0.71       736
# weighted avg       0.97      0.92      0.94       736
#
#
# ==================================================
#
# Model saved to random_forest_model.joblib
# Processing file: TCS.csv
# Results for TCS.csv:
# Accuracy: 0.9782608695652174
# Classification Report:
#                precision    recall  f1-score   support
#
#        False       1.00      0.98      0.99       726
#         True       0.38      1.00      0.56        10
#
#     accuracy                           0.98       736
#    macro avg       0.69      0.99      0.77       736
# weighted avg       0.99      0.98      0.98       736
#
#
# ==================================================
#
# Model saved to random_forest_model.joblib
# Processing file: TECHM.csv
# Results for TECHM.csv:
# Accuracy: 0.9605978260869565
# Classification Report:
#                precision    recall  f1-score   support
#
#        False       1.00      0.96      0.98       720
#         True       0.36      1.00      0.52        16
#
#     accuracy                           0.96       736
#    macro avg       0.68      0.98      0.75       736
# weighted avg       0.99      0.96      0.97       736
#
#
# ==================================================
#
# Model saved to random_forest_model.joblib
# Processing file: TITAN.csv
# Results for TITAN.csv:
# Accuracy: 0.9510869565217391
# Classification Report:
#                precision    recall  f1-score   support
#
#        False       0.99      0.96      0.97       719
#         True       0.29      0.76      0.42        17
#
#     accuracy                           0.95       736
#    macro avg       0.64      0.86      0.70       736
# weighted avg       0.98      0.95      0.96       736
#
#
# ==================================================
#
# Model saved to random_forest_model.joblib
# Model loaded successfully
# Processing symbol: AAPL
# [*********************100%***********************]  1 of 1 completed
# C:\Users\tanis\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\base.py:486: UserWarning: X has feature names, but RandomForestClassifier was fitted without feature names
#   warnings.warn(
# [*********************100%***********************]  1 of 1 completed
# Real-time prediction for AAPL: Positive
# --------------------------------------------------
# Processing symbol: GOOGL
# Real-time prediction for GOOGL: Positive
# --------------------------------------------------
# Processing symbol: MSFT
# C:\Users\tanis\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\base.py:486: UserWarning: X has feature names, but RandomForestClassifier was fitted without feature names
#   warnings.warn(
# [*********************100%***********************]  1 of 1 completed
# C:\Users\tanis\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\base.py:486: UserWarning: X has feature names, but RandomForestClassifier was fitted without feature names
#   warnings.warn(
# [*********************100%***********************]  1 of 1 completed
# Real-time prediction for MSFT: Positive
# --------------------------------------------------
# Processing symbol: EURUSD=X
# [*********************100%***********************]  1 of 1 completed
# --------------------------------------------------
# Processing symbol: GBPUSD=X
# --------------------------------------------------
# Processing symbol: JPY=X
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# --------------------------------------------------
# Processing symbol: BTC-USD
# C:\Users\tanis\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\base.py:486: UserWarning: X has feature names, but RandomForestClassifier was fitted without feature names
#   warnings.warn(
# Real-time prediction for BTC-USD: Negative
# --------------------------------------------------
# Processing symbol: ETH-USD
# [*********************100%***********************]  1 of 1 completed
# C:\Users\tanis\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\base.py:486: UserWarning: X has feature names, but RandomForestClassifier was fitted without feature names
#   warnings.warn(
# Real-time prediction for ETH-USD: Negative
# --------------------------------------------------
